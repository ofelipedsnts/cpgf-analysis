# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

# %%
import pandas as pd
from src.cleanner import normalize_columns, transform_str_to_float, transform_to_datetime
from src.loader import load_data

# %%
df = load_data()

# %%
df = normalize_columns(df)
df = transform_str_to_float(df)
df = transform_to_datetime(df)

# %%
output_path = Path().resolve().parent / "data" / "processed" / "cpgf-2025.csv"

df.to_csv(output_path, index=False, encoding="utf-8")

print(f"Arquivo exportado: {output_path}")
# Out:
# Arquivo exportado: /Users/felipe/Projetos/cpgf-analysis/data/processed/cpgf-2025.csv
