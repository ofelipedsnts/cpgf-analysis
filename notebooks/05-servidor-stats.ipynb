# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

# %%
import pandas as pd
from src.exporter import export_data_by_servidor

# %%
df = pd.read_csv("../data/processed/cpgf-2025.csv")

# %%
export_data_by_servidor(df)
# Out:
# [export_data_by_servidor]: Arquivo exportado com sucesso /Users/felipe/Projetos/cpgf-analysis/data/processed/resumo_servidores.csv
