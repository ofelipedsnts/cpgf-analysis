# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

# %%
import pandas as pd
from src.exporter import export_saques_dataframe

# %%
df = pd.read_csv("../data/processed/cpgf-2025.csv")

# %%
export_saques_dataframe(df)
# Out:
# [export_saques]: Arquivo exportado com sucesso /Users/felipe/Projetos/cpgf-analysis/data/processed/transacoes_de_saque.csv
