# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

# %%
import pandas as pd
from src.exporter import export_data_by_orgao

# %%
df = pd.read_csv("../data/processed/cpgf-2025.csv")

# %%
export_data_by_orgao(df)
# Out:
# Arquivo exportado com sucesso /Users/felipe/Projetos/cpgf-analysis/data/processed/total-gastos-por-orgao.csv
